# %% [markdown]
# <a href="https://colab.research.google.com/github/Meenakshigupta6527/Data-Acquisition-Data-wrangling/blob/main/Data_Acquisition_Data_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
dataset_1=pd.read_excel('/content/drive/MyDrive/Internship_Project2/dataset_1.xlsx')

# %%
dataset_1
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# ...

# %%
dataset_1['season'].unique()
# Out:
# array([1])

# %%
dataset_1.drop(['season'],axis=1,inplace=True)

# %%
dataset_1
# Out:
#      instant     dteday  yr  mnth  hr  holiday  weekday  weathersit  temp
# 0          1 2011-01-01   0     1   0    False        6           1  0.24
# 1          2 2011-01-01   0     1   1    False        6           1  0.22
# 2          3 2011-01-01   0     1   2    False        6           1  0.22
# 3          4 2011-01-01   0     1   3    False        6           1  0.24
# 4          5 2011-01-01   0     1   4    False        6           1  0.24
# ..       ...        ...  ..   ...  ..      ...      ...         ...   ...
# 605      606 2011-01-28   0     1  11    False        5           3  0.18
# 606      607 2011-01-28   0     1  12    False        5           3  0.18
# 607      608 2011-01-28   0     1  13    False        5           3  0.18
# 608      609 2011-01-28   0     1  14    False        5           3  0.22
# 609      610 2011-01-28   0     1  15    False        5           2  0.20
#
# [610 rows x 9 columns]

# %%
dataset_1['mnth'].unique()
# Out:
# array([1])

# %%
dataset_1.drop(['mnth'],axis=1,inplace=True)

# %%
dataset_1
# Out:
#      instant     dteday  yr  hr  holiday  weekday  weathersit  temp
# 0          1 2011-01-01   0   0    False        6           1  0.24
# 1          2 2011-01-01   0   1    False        6           1  0.22
# 2          3 2011-01-01   0   2    False        6           1  0.22
# 3          4 2011-01-01   0   3    False        6           1  0.24
# 4          5 2011-01-01   0   4    False        6           1  0.24
# ..       ...        ...  ..  ..      ...      ...         ...   ...
# 605      606 2011-01-28   0  11    False        5           3  0.18
# 606      607 2011-01-28   0  12    False        5           3  0.18
# 607      608 2011-01-28   0  13    False        5           3  0.18
# 608      609 2011-01-28   0  14    False        5           3  0.22
# 609      610 2011-01-28   0  15    False        5           2  0.20
#
# [610 rows x 8 columns]

# %%
dataset_1['yr'].unique()
# Out:
# array([0])

# %%
dataset_1.drop(['yr'],axis=1,inplace=True)
dataset_1
# Out:
#      instant     dteday  hr  holiday  weekday  weathersit  temp
# 0          1 2011-01-01   0    False        6           1  0.24
# 1          2 2011-01-01   1    False        6           1  0.22
# 2          3 2011-01-01   2    False        6           1  0.22
# 3          4 2011-01-01   3    False        6           1  0.24
# 4          5 2011-01-01   4    False        6           1  0.24
# ..       ...        ...  ..      ...      ...         ...   ...
# 605      606 2011-01-28  11    False        5           3  0.18
# 606      607 2011-01-28  12    False        5           3  0.18
# 607      608 2011-01-28  13    False        5           3  0.18
# 608      609 2011-01-28  14    False        5           3  0.22
# 609      610 2011-01-28  15    False        5           2  0.20
#
# [610 rows x 7 columns]

# %%
dataset_1['holiday'].unique()
# Out:
# array([False,  True])

# %%
dataset_1.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# dtype: object

# %%
dataset_1['holiday']=dataset_1['holiday'].astype(int)
dataset_1.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# hr                     int64
# holiday                int64
# weekday                int64
# weathersit             int64
# temp                 float64
# dtype: object

# %%
dataset_1
# Out:
#      instant     dteday  hr  holiday  weekday  weathersit  temp
# 0          1 2011-01-01   0        0        6           1  0.24
# 1          2 2011-01-01   1        0        6           1  0.22
# 2          3 2011-01-01   2        0        6           1  0.22
# 3          4 2011-01-01   3        0        6           1  0.24
# 4          5 2011-01-01   4        0        6           1  0.24
# ..       ...        ...  ..      ...      ...         ...   ...
# 605      606 2011-01-28  11        0        5           3  0.18
# 606      607 2011-01-28  12        0        5           3  0.18
# 607      608 2011-01-28  13        0        5           3  0.18
# 608      609 2011-01-28  14        0        5           3  0.22
# 609      610 2011-01-28  15        0        5           2  0.20
#
# [610 rows x 7 columns]

# %%
dataset_1['holiday'].unique()
# Out:
# array([0, 1])

# %%
dataset_1.duplicated().sum()
# Out:
# 0

# %%
dataset_1.isnull().sum()
# Out:
# instant       0
# dteday        0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
dataset_1.shape
# Out:
# (610, 7)

# %%
dataset_2=pd.read_excel('/content/drive/MyDrive/Internship_Project2/dataset_2.xlsx')

# %%
dataset_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
dataset_2.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
dataset_2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
dataset_2.dtypes
# Out:
# instant         int64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
dataset_2.duplicated().sum()
# Out:
# 0

# %%
dataset_2.isnull().sum()
# Out:
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
dataset_2.describe()
# Out:
#           instant       atemp         hum   windspeed      casual  registered  \
# count  610.000000  599.000000  610.000000  610.000000  610.000000  610.000000
# mean   305.500000    0.199935    0.562475    0.204851    4.501639   51.068852
# std    176.236111    0.078836    0.175440    0.121806    6.319945   47.021204
# min      1.000000    0.000000    0.210000    0.000000    0.000000    0.000000
# 25%    153.250000    0.151500    0.432500    0.104500    0.000000   14.000000
# 50%    305.500000    0.197000    0.520000    0.194000    2.000000   43.000000
# 75%    457.750000    0.242400    0.690000    0.283600    6.000000   70.000000
# max    610.000000    0.454500    1.000000    0.582100   47.000000  247.000000
#
#               cnt
# count  610.000000
# mean    55.570492
# std     49.316802
# min      1.000000
# 25%     16.000000
# 50%     47.000000
# 75%     79.750000
# max    249.000000

# %%
combine_data= pd.merge(dataset_1,dataset_2,on='instant',how='inner')
combine_data
# Out:
#      instant     dteday  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0          1 2011-01-01   0        0        6           1  0.24  0.2879  0.81
# 1          2 2011-01-01   1        0        6           1  0.22  0.2727  0.80
# 2          3 2011-01-01   2        0        6           1  0.22  0.2727  0.80
# 3          4 2011-01-01   3        0        6           1  0.24  0.2879  0.75
# 4          5 2011-01-01   4        0        6           1  0.24  0.2879  0.75
# ..       ...        ...  ..      ...      ...         ...   ...     ...   ...
# 605      606 2011-01-28  11        0        5           3  0.18  0.2121  0.93
# 606      607 2011-01-28  12        0        5           3  0.18  0.2121  0.93
# 607      608 2011-01-28  13        0        5           3  0.18  0.2121  0.93
# 608      609 2011-01-28  14        0        5           3  0.22  0.2727  0.80
# 609      610 2011-01-28  15        0        5           2  0.20  0.2576  0.86
#
# ...

# %%
combine_data.shape
# Out:
# (610, 13)

# %%
combine_data.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# hr                     int64
# holiday                int64
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
combine_data
# Out:
#      instant     dteday  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0          1 2011-01-01   0        0        6           1  0.24  0.2879  0.81
# 1          2 2011-01-01   1        0        6           1  0.22  0.2727  0.80
# 2          3 2011-01-01   2        0        6           1  0.22  0.2727  0.80
# 3          4 2011-01-01   3        0        6           1  0.24  0.2879  0.75
# 4          5 2011-01-01   4        0        6           1  0.24  0.2879  0.75
# ..       ...        ...  ..      ...      ...         ...   ...     ...   ...
# 605      606 2011-01-28  11        0        5           3  0.18  0.2121  0.93
# 606      607 2011-01-28  12        0        5           3  0.18  0.2121  0.93
# 607      608 2011-01-28  13        0        5           3  0.18  0.2121  0.93
# 608      609 2011-01-28  14        0        5           3  0.22  0.2727  0.80
# 609      610 2011-01-28  15        0        5           2  0.20  0.2576  0.86
#
# ...

# %%
#combine_data['int'] = pd.to_datetime(combine_data['dteday']).astype(np.int64)

# %%
combine_data['dteday'] = combine_data['dteday'].astype(int)

# %%
combine_data
# Out:
#      instant               dteday  hr  holiday  weekday  weathersit  temp  \
# 0          1  1293840000000000000   0        0        6           1  0.24
# 1          2  1293840000000000000   1        0        6           1  0.22
# 2          3  1293840000000000000   2        0        6           1  0.22
# 3          4  1293840000000000000   3        0        6           1  0.24
# 4          5  1293840000000000000   4        0        6           1  0.24
# ..       ...                  ...  ..      ...      ...         ...   ...
# 605      606  1296172800000000000  11        0        5           3  0.18
# 606      607  1296172800000000000  12        0        5           3  0.18
# 607      608  1296172800000000000  13        0        5           3  0.18
# 608      609  1296172800000000000  14        0        5           3  0.22
# 609      610  1296172800000000000  15        0        5           2  0.20
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
combine_data.duplicated().sum()
# Out:
# 0

# %%
combine_data.isnull().sum()
# Out:
# instant        0
# dteday         0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
combine_data['atemp'].replace('?',np.nan,inplace=True)

# %%
combine_data
# Out:
#      instant               dteday  hr  holiday  weekday  weathersit  temp  \
# 0          1  1293840000000000000   0        0        6           1  0.24
# 1          2  1293840000000000000   1        0        6           1  0.22
# 2          3  1293840000000000000   2        0        6           1  0.22
# 3          4  1293840000000000000   3        0        6           1  0.24
# 4          5  1293840000000000000   4        0        6           1  0.24
# ..       ...                  ...  ..      ...      ...         ...   ...
# 605      606  1296172800000000000  11        0        5           3  0.18
# 606      607  1296172800000000000  12        0        5           3  0.18
# 607      608  1296172800000000000  13        0        5           3  0.18
# 608      609  1296172800000000000  14        0        5           3  0.22
# 609      610  1296172800000000000  15        0        5           2  0.20
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
combine_data['atemp'].unique()
# Out:
# array([0.2879, 0.2727, 0.2576,    nan, 0.3485, 0.3939, 0.3333, 0.4242,
#        0.4545, 0.4394, 0.4091, 0.2273, 0.2121, 0.197 , 0.1364, 0.1061,
#        0.1212, 0.1667, 0.1818, 0.2424, 0.1515, 0.3182, 0.0606, 0.0758,
#        0.0909, 0.303 , 0.0303, 0.0455, 0.    , 0.0152])

# %%
combine_data['atemp'].isnull().sum()/combine_data['atemp'].shape[0]*100
# Out:
# 1.8032786885245904

# %%
atemp_mean=combine_data['atemp'].mean()

# %%
atemp_mean
# Out:
# 0.0

# %%
combine_data = combine_data.fillna(atemp_mean)
combine_data
# Out:
#      instant               dteday  hr  holiday  weekday  weathersit  temp  \
# 0          1  1293840000000000000   0        0        6           1  0.24
# 1          2  1293840000000000000   1        0        6           1  0.22
# 2          3  1293840000000000000   2        0        6           1  0.22
# 3          4  1293840000000000000   3        0        6           1  0.24
# 4          5  1293840000000000000   4        0        6           1  0.24
# ..       ...                  ...  ..      ...      ...         ...   ...
# 605      606  1296172800000000000  11        0        5           3  0.18
# 606      607  1296172800000000000  12        0        5           3  0.18
# 607      608  1296172800000000000  13        0        5           3  0.18
# 608      609  1296172800000000000  14        0        5           3  0.22
# 609      610  1296172800000000000  15        0        5           2  0.20
#
#       atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
combine_data['atemp'].median()
# Out:
# 0.197

# %%
combine_data['atemp'].isnull().sum()
# Out:
# 0

# %%
combine_data = combine_data.astype({"atemp": 'int',"temp": 'int', "hum": 'int', "windspeed": 'int'})
combine_data.dtypes
# Out:
# instant       int64
# dteday        int64
# hr            int64
# holiday       int64
# weekday       int64
# weathersit    int64
# temp          int64
# atemp         int64
# hum           int64
# windspeed     int64
# casual        int64
# registered    int64
# cnt           int64
# dtype: object

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset_3=pd.read_excel('/content/drive/MyDrive/Internship_Project2/dataset_3.xlsx')

# %%
dataset_3
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620 2011-01-29       1   0     1   1    False        6           1
# 1        621 2011-01-29       1   0     1   2    False        6           1
# 2        622 2011-01-29       1   0     1   3    False        6           1
# 3        623 2011-01-29       1   0     1   4    False        6           1
# 4        624 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
# ...

# %%
dataset_3.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
dataset_3['dteday'] = dataset_3['dteday'].astype(int)

# %%
dataset_3
# Out:
#      instant               dteday  season  yr  mnth  hr  holiday  weekday  \
# 0        620  1296259200000000000       1   0     1   1    False        6
# 1        621  1296259200000000000       1   0     1   2    False        6
# 2        622  1296259200000000000       1   0     1   3    False        6
# 3        623  1296259200000000000       1   0     1   4    False        6
# 4        624  1296259200000000000       1   0     1   6    False        6
# ..       ...                  ...     ...  ..   ...  ..      ...      ...
# 385      615  1296172800000000000       1   0     1  20    False        5
# 386      616  1296172800000000000       1   0     1  21    False        5
# 387      617  1296172800000000000       1   0     1  22    False        5
# 388      618  1296172800000000000       1   0     1  23    False        5
# 389      619  1296259200000000000       1   0     1   0    False        6
#
#      weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
dataset_3_int = dataset_3.astype({"atemp": 'int',"holiday": 'int',"temp": 'int', "hum": 'int', "windspeed": 'int'})
dataset_3_int.dtypes
# Out:
# instant       int64
# dteday        int64
# season        int64
# yr            int64
# mnth          int64
# hr            int64
# holiday       int64
# weekday       int64
# weathersit    int64
# temp          int64
# atemp         int64
# hum           int64
# windspeed     int64
# casual        int64
# registered    int64
# cnt           int64
# dtype: object

# %%
dataset_3.duplicated().sum()
# Out:
# 0

# %%
dataset_3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
dataset_3.describe()
# Out:
#            instant        dteday  season     yr        mnth          hr  \
# count   390.000000  3.900000e+02   390.0  390.0  390.000000  390.000000
# mean    805.500000  1.296906e+18     1.0    0.0    1.800000   11.687179
# std     112.727548  4.164954e+14     0.0    0.0    0.400514    6.980295
# min     611.000000  1.296173e+18     1.0    0.0    1.000000    0.000000
# 25%     708.250000  1.296518e+18     1.0    0.0    2.000000    6.000000
# 50%     805.500000  1.296907e+18     1.0    0.0    2.000000   12.000000
# 75%     902.750000  1.297296e+18     1.0    0.0    2.000000   18.000000
# max    1000.000000  1.297642e+18     1.0    0.0    2.000000   23.000000
#
#           weekday  weathersit        temp       atemp         hum   windspeed  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean     2.989744    1.484615    0.220000    0.230424    0.613769    0.179416
# std      2.149884    0.663805    0.073095    0.069455    0.202361    0.138551
# ...

# %%
dataset_3['season'].unique()
# Out:
# array([1])

# %%
dataset_3.drop(['season'],axis=1,inplace=True)

# %%
dataset_3
# Out:
#      instant               dteday  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  1296259200000000000   0     1   1    False        6           1
# 1        621  1296259200000000000   0     1   2    False        6           1
# 2        622  1296259200000000000   0     1   3    False        6           1
# 3        623  1296259200000000000   0     1   4    False        6           1
# 4        624  1296259200000000000   0     1   6    False        6           1
# ..       ...                  ...  ..   ...  ..      ...      ...         ...
# 385      615  1296172800000000000   0     1  20    False        5           2
# 386      616  1296172800000000000   0     1  21    False        5           2
# 387      617  1296172800000000000   0     1  22    False        5           1
# 388      618  1296172800000000000   0     1  23    False        5           1
# 389      619  1296259200000000000   0     1   0    False        6           1
#
# ...

# %%
dataset_3['mnth'].unique()
# Out:
# array([1, 2])

# %%
dataset_3['yr'].unique()
# Out:
# array([0])

# %%
dataset_3.drop(['yr'],axis=1,inplace=True)

# %%
dataset_3
# Out:
#      instant               dteday  mnth  hr  holiday  weekday  weathersit  \
# 0        620  1296259200000000000     1   1    False        6           1
# 1        621  1296259200000000000     1   2    False        6           1
# 2        622  1296259200000000000     1   3    False        6           1
# 3        623  1296259200000000000     1   4    False        6           1
# 4        624  1296259200000000000     1   6    False        6           1
# ..       ...                  ...   ...  ..      ...      ...         ...
# 385      615  1296172800000000000     1  20    False        5           2
# 386      616  1296172800000000000     1  21    False        5           2
# 387      617  1296172800000000000     1  22    False        5           1
# 388      618  1296172800000000000     1  23    False        5           1
# 389      619  1296259200000000000     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
dataset_3.shape
# Out:
# (390, 14)

# %%
dataset_3
# Out:
#      instant               dteday  mnth  hr  holiday  weekday  weathersit  \
# 0        620  1296259200000000000     1   1    False        6           1
# 1        621  1296259200000000000     1   2    False        6           1
# 2        622  1296259200000000000     1   3    False        6           1
# 3        623  1296259200000000000     1   4    False        6           1
# 4        624  1296259200000000000     1   6    False        6           1
# ..       ...                  ...   ...  ..      ...      ...         ...
# 385      615  1296172800000000000     1  20    False        5           2
# 386      616  1296172800000000000     1  21    False        5           2
# 387      617  1296172800000000000     1  22    False        5           1
# 388      618  1296172800000000000     1  23    False        5           1
# 389      619  1296259200000000000     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# ...

# %%
#horizontal_concat_data = pd.concat([combine_data, dataset_3], axis=1)
#horizontal_concat_data
# Out:
#      instant               dteday  hr  holiday  weekday  weathersit  temp  \
# 0          1  1293840000000000000   0        0        6           1     0
# 1          2  1293840000000000000   1        0        6           1     0
# 2          3  1293840000000000000   2        0        6           1     0
# 3          4  1293840000000000000   3        0        6           1     0
# 4          5  1293840000000000000   4        0        6           1     0
# ..       ...                  ...  ..      ...      ...         ...   ...
# 605      606  1296172800000000000  11        0        5           3     0
# 606      607  1296172800000000000  12        0        5           3     0
# 607      608  1296172800000000000  13        0        5           3     0
# 608      609  1296172800000000000  14        0        5           3     0
# 609      610  1296172800000000000  15        0        5           2     0
#
#      atemp  hum  windspeed  ...  holiday  weekday  weathersit  temp   atemp  \
# ...

# %%
vertical_concat_data = pd.concat([combine_data, dataset_3], axis=0)
vertical_concat_data
# Out:
#      instant               dteday  hr  holiday  weekday  weathersit  temp  \
# 0          1  1293840000000000000   0        0        6           1  0.00
# 1          2  1293840000000000000   1        0        6           1  0.00
# 2          3  1293840000000000000   2        0        6           1  0.00
# 3          4  1293840000000000000   3        0        6           1  0.00
# 4          5  1293840000000000000   4        0        6           1  0.00
# ..       ...                  ...  ..      ...      ...         ...   ...
# 385      615  1296172800000000000  20        0        5           2  0.24
# 386      616  1296172800000000000  21        0        5           2  0.22
# 387      617  1296172800000000000  22        0        5           1  0.24
# 388      618  1296172800000000000  23        0        5           1  0.24
# 389      619  1296259200000000000   0        0        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt  mnth
# ...

# %%
vertical_concat_data.isnull().sum()
# Out:
# instant         0
# dteday          0
# hr              0
# holiday         0
# weekday         0
# weathersit      0
# temp            0
# atemp           0
# hum             0
# windspeed       0
# casual          0
# registered      0
# cnt             0
# mnth          610
# dtype: int64

# %%
mnth_mean=vertical_concat_data['mnth'].mean()

# %%
mnth_mean
# Out:
# 1.8

# %%
vertical_concat_data = vertical_concat_data.fillna(mnth_mean)

# %%
vertical_concat_data
# Out:
#      instant               dteday  hr  holiday  weekday  weathersit  temp  \
# 0          1  1293840000000000000   0        0        6           1  0.00
# 1          2  1293840000000000000   1        0        6           1  0.00
# 2          3  1293840000000000000   2        0        6           1  0.00
# 3          4  1293840000000000000   3        0        6           1  0.00
# 4          5  1293840000000000000   4        0        6           1  0.00
# ..       ...                  ...  ..      ...      ...         ...   ...
# 385      615  1296172800000000000  20        0        5           2  0.24
# 386      616  1296172800000000000  21        0        5           2  0.22
# 387      617  1296172800000000000  22        0        5           1  0.24
# 388      618  1296172800000000000  23        0        5           1  0.24
# 389      619  1296259200000000000   0        0        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt  mnth
# ...

# %%
vertical_concat_data.isnull().sum()
# Out:
# instant       0
# dteday        0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# mnth          0
# dtype: int64

# %%
vertical_concat_data.dtypes
# Out:
# instant         int64
# dteday          int64
# hr              int64
# holiday         int64
# weekday         int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# mnth          float64
# dtype: object

# %%
vertical_concat_data.describe()
# Out:
#            instant        dteday           hr      holiday      weekday  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.000000
# mean    500.500000  1.295712e+18    11.753000     0.024000     2.982000
# std     288.819436  1.121563e+15     6.899101     0.153126     2.091423
# min       1.000000  1.293840e+18     0.000000     0.000000     0.000000
# 25%     250.750000  1.294704e+18     6.000000     0.000000     1.000000
# 50%     500.500000  1.295654e+18    12.000000     0.000000     3.000000
# 75%     750.250000  1.296691e+18    18.000000     0.000000     5.000000
# max    1000.000000  1.297642e+18    23.000000     1.000000     6.000000
#
#         weathersit         temp        atemp          hum    windspeed  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      1.480000     0.085800     0.089865     0.240370     0.069972
# std       0.651171     0.116646     0.120509     0.325846     0.123047
# ...

# %%
old_shape=vertical_concat_data.shape
old_shape
# Out:
# (1000, 14)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(vertical_concat_data['registered']).set(title="Box Plot of registered")
# Out:
# [Text(0.5, 1.0, 'Box Plot of registered')]

# %%
IQR = 74-15 #Q3-Q1
print(IQR)
lower_limit = 15 - 1.5*IQR
upper_limit = 74 + 1.5*IQR
print(upper_limit)
print(lower_limit)
# Out:
# 59
# 162.5
# -73.5

# %%
df_registered_filtered = vertical_concat_data['registered'][(vertical_concat_data['registered']>lower_limit) & (vertical_concat_data['registered']<upper_limit)]
print(df_registered_filtered)
# Out:
# 0      13
# 1      32
# 2      27
# 3      10
# 4       1
#        ..
# 385    61
# 386    57
# 387    26
# 388    22
# 389    26
# Name: registered, Length: 955, dtype: int64

# %%
New_shape=df_registered_filtered.shape
New_shape
# Out:
# (955,)

# %%
vertical_concat_data.skew()
# Out:
# instant       0.000000
# dteday        0.007008
# hr           -0.063524
# holiday       6.229578
# weekday       0.021925
# weathersit    1.044098
# temp          0.926796
# atemp         0.853230
# hum           0.888485
# windspeed     1.826516
# casual        3.414105
# registered    1.296723
# cnt           1.137709
# mnth         -2.405532
# dtype: float64

# %%
vertical_concat_data.corr(method='pearson')
# Out:
#              instant    dteday        hr       holiday   weekday  weathersit  \
# instant     1.000000  0.999540  0.000060 -6.301291e-02  0.008157    0.030439
# dteday      0.999540  1.000000 -0.022421 -6.845599e-02  0.010248    0.033310
# hr          0.000060 -0.022421  1.000000 -5.753419e-03  0.007531   -0.055802
# holiday    -0.063013 -0.068456 -0.005753  1.000000e+00 -0.148682    0.165443
# weekday     0.008157  0.010248  0.007531 -1.486825e-01  1.000000    0.060007
# weathersit  0.030439  0.033310 -0.055802  1.654431e-01  0.060007    1.000000
# temp        0.793166  0.797598  0.061811 -1.154022e-01 -0.069818   -0.017976
# atemp       0.798590  0.803811  0.044027 -1.169959e-01 -0.071020   -0.003072
# hum         0.733406  0.743339 -0.063046 -1.157351e-01  0.010762    0.138710
# windspeed   0.636421  0.638666  0.037643 -8.921795e-02  0.012558   -0.098315
# casual      0.071259  0.065002  0.204476 -9.441497e-04 -0.047363   -0.096346
# ...
