# %% [markdown]
# <a href="https://colab.research.google.com/github/Meenakshigupta6527/Data-Acquisition-Data-wrangling/blob/main/Data_Acquisition_Data_Wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
dataset_1=pd.read_excel('/content/drive/MyDrive/Internship_Project2/dataset_1.xlsx')

# %%
dataset_1
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# 2    0.22
# 3    0.24
# 4    0.24
# ..    ...
# 605  0.18
# 606  0.18
# 607  0.18
# 608  0.22
# 609  0.20
#
# [610 rows x 10 columns]

# %%
dataset_1['season'].unique()
# Out:
# array([1])

# %%
dataset_1.drop(['season'],axis=1,inplace=True)

# %%
dataset_1
# Out:
#      instant     dteday  yr  mnth  hr  holiday  weekday  weathersit  temp
# 0          1 2011-01-01   0     1   0    False        6           1  0.24
# 1          2 2011-01-01   0     1   1    False        6           1  0.22
# 2          3 2011-01-01   0     1   2    False        6           1  0.22
# 3          4 2011-01-01   0     1   3    False        6           1  0.24
# 4          5 2011-01-01   0     1   4    False        6           1  0.24
# ..       ...        ...  ..   ...  ..      ...      ...         ...   ...
# 605      606 2011-01-28   0     1  11    False        5           3  0.18
# 606      607 2011-01-28   0     1  12    False        5           3  0.18
# 607      608 2011-01-28   0     1  13    False        5           3  0.18
# 608      609 2011-01-28   0     1  14    False        5           3  0.22
# 609      610 2011-01-28   0     1  15    False        5           2  0.20
#
# [610 rows x 9 columns]

# %%
dataset_1['mnth'].unique()
# Out:
# array([1])

# %%
dataset_1.drop(['mnth'],axis=1,inplace=True)

# %%
dataset_1
# Out:
#      instant     dteday  yr  hr  holiday  weekday  weathersit  temp
# 0          1 2011-01-01   0   0    False        6           1  0.24
# 1          2 2011-01-01   0   1    False        6           1  0.22
# 2          3 2011-01-01   0   2    False        6           1  0.22
# 3          4 2011-01-01   0   3    False        6           1  0.24
# 4          5 2011-01-01   0   4    False        6           1  0.24
# ..       ...        ...  ..  ..      ...      ...         ...   ...
# 605      606 2011-01-28   0  11    False        5           3  0.18
# 606      607 2011-01-28   0  12    False        5           3  0.18
# 607      608 2011-01-28   0  13    False        5           3  0.18
# 608      609 2011-01-28   0  14    False        5           3  0.22
# 609      610 2011-01-28   0  15    False        5           2  0.20
#
# [610 rows x 8 columns]

# %%
dataset_1['yr'].unique()
# Out:
# array([0])

# %%
dataset_1.drop(['yr'],axis=1,inplace=True)
dataset_1
# Out:
#      instant     dteday  hr  holiday  weekday  weathersit  temp
# 0          1 2011-01-01   0    False        6           1  0.24
# 1          2 2011-01-01   1    False        6           1  0.22
# 2          3 2011-01-01   2    False        6           1  0.22
# 3          4 2011-01-01   3    False        6           1  0.24
# 4          5 2011-01-01   4    False        6           1  0.24
# ..       ...        ...  ..      ...      ...         ...   ...
# 605      606 2011-01-28  11    False        5           3  0.18
# 606      607 2011-01-28  12    False        5           3  0.18
# 607      608 2011-01-28  13    False        5           3  0.18
# 608      609 2011-01-28  14    False        5           3  0.22
# 609      610 2011-01-28  15    False        5           2  0.20
#
# [610 rows x 7 columns]

# %%
dataset_1['holiday'].unique()
# Out:
# array([False,  True])

# %%
dataset_1.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# dtype: object

# %%
dataset_1['holiday']=dataset_1['holiday'].astype(int)
dataset_1.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# hr                     int64
# holiday                int64
# weekday                int64
# weathersit             int64
# temp                 float64
# dtype: object

# %%
dataset_1
# Out:
#      instant     dteday  hr  holiday  weekday  weathersit  temp
# 0          1 2011-01-01   0        0        6           1  0.24
# 1          2 2011-01-01   1        0        6           1  0.22
# 2          3 2011-01-01   2        0        6           1  0.22
# 3          4 2011-01-01   3        0        6           1  0.24
# 4          5 2011-01-01   4        0        6           1  0.24
# ..       ...        ...  ..      ...      ...         ...   ...
# 605      606 2011-01-28  11        0        5           3  0.18
# 606      607 2011-01-28  12        0        5           3  0.18
# 607      608 2011-01-28  13        0        5           3  0.18
# 608      609 2011-01-28  14        0        5           3  0.22
# 609      610 2011-01-28  15        0        5           2  0.20
#
# [610 rows x 7 columns]

# %%
dataset_1['holiday'].unique()
# Out:
# array([0, 1])

# %%
dataset_1.duplicated().sum()
# Out:
# 0

# %%
dataset_1.isnull().sum()
# Out:
# instant       0
# dteday        0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
dataset_1.shape
# Out:
# (610, 7)

# %%
dataset_2=pd.read_excel('/content/drive/MyDrive/Internship_Project2/dataset_2.xlsx')

# %%
dataset_2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
dataset_2.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
dataset_2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
dataset_2.dtypes
# Out:
# instant         int64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
dataset_2.duplicated().sum()
# Out:
# 0

# %%
dataset_2.isnull().sum()
# Out:
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
dataset_2.describe()
# Out:
#           instant       atemp         hum   windspeed      casual  registered  \
# count  610.000000  599.000000  610.000000  610.000000  610.000000  610.000000
# mean   305.500000    0.199935    0.562475    0.204851    4.501639   51.068852
# std    176.236111    0.078836    0.175440    0.121806    6.319945   47.021204
# min      1.000000    0.000000    0.210000    0.000000    0.000000    0.000000
# 25%    153.250000    0.151500    0.432500    0.104500    0.000000   14.000000
# 50%    305.500000    0.197000    0.520000    0.194000    2.000000   43.000000
# 75%    457.750000    0.242400    0.690000    0.283600    6.000000   70.000000
# max    610.000000    0.454500    1.000000    0.582100   47.000000  247.000000
#
#               cnt
# count  610.000000
# mean    55.570492
# std     49.316802
# min      1.000000
# 25%     16.000000
# 50%     47.000000
# 75%     79.750000
# max    249.000000

# %%
combine_data= pd.merge(dataset_1,dataset_2,on='instant',how='inner')
combine_data
# Out:
#      instant     dteday  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0          1 2011-01-01   0        0        6           1  0.24  0.2879  0.81
# 1          2 2011-01-01   1        0        6           1  0.22  0.2727  0.80
# 2          3 2011-01-01   2        0        6           1  0.22  0.2727  0.80
# 3          4 2011-01-01   3        0        6           1  0.24  0.2879  0.75
# 4          5 2011-01-01   4        0        6           1  0.24  0.2879  0.75
# ..       ...        ...  ..      ...      ...         ...   ...     ...   ...
# 605      606 2011-01-28  11        0        5           3  0.18  0.2121  0.93
# 606      607 2011-01-28  12        0        5           3  0.18  0.2121  0.93
# 607      608 2011-01-28  13        0        5           3  0.18  0.2121  0.93
# 608      609 2011-01-28  14        0        5           3  0.22  0.2727  0.80
# 609      610 2011-01-28  15        0        5           2  0.20  0.2576  0.86
#
#      windspeed  casual  registered  cnt
# 0       0.0000       3          13   16
# 1       0.0000       8          32   40
# 2       0.0000       5          27   32
# 3       0.0000       3          10   13
# 4       0.0000       0           1    1
# ..         ...     ...         ...  ...
# 605     0.1045       0          30   30
# 606     0.1045       1          28   29
# 607     0.1045       0          31   31
# 608     0.0000       2          36   38
# 609     0.0000       1          40   41
#
# [610 rows x 13 columns]

# %%
combine_data.shape
# Out:
# (610, 13)

# %%
combine_data.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# hr                     int64
# holiday                int64
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
combine_data
# Out:
#      instant     dteday  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0          1 2011-01-01   0        0        6           1  0.24  0.2879  0.81
# 1          2 2011-01-01   1        0        6           1  0.22  0.2727  0.80
# 2          3 2011-01-01   2        0        6           1  0.22  0.2727  0.80
# 3          4 2011-01-01   3        0        6           1  0.24  0.2879  0.75
# 4          5 2011-01-01   4        0        6           1  0.24  0.2879  0.75
# ..       ...        ...  ..      ...      ...         ...   ...     ...   ...
# 605      606 2011-01-28  11        0        5           3  0.18  0.2121  0.93
# 606      607 2011-01-28  12        0        5           3  0.18  0.2121  0.93
# 607      608 2011-01-28  13        0        5           3  0.18  0.2121  0.93
# 608      609 2011-01-28  14        0        5           3  0.22  0.2727  0.80
# 609      610 2011-01-28  15        0        5           2  0.20  0.2576  0.86
#
#      windspeed  casual  registered  cnt
# 0       0.0000       3          13   16
# 1       0.0000       8          32   40
# 2       0.0000       5          27   32
# 3       0.0000       3          10   13
# 4       0.0000       0           1    1
# ..         ...     ...         ...  ...
# 605     0.1045       0          30   30
# 606     0.1045       1          28   29
# 607     0.1045       0          31   31
# 608     0.0000       2          36   38
# 609     0.0000       1          40   41
#
# [610 rows x 13 columns]

# %%
combine_data.duplicated().sum()
# Out:
# 0

# %%
combine_data.isnull().sum()
# Out:
# instant        0
# dteday         0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
combine_data['atemp'].replace('?',np.nan,inplace=True)

# %%
combine_data
# Out:
#      instant     dteday  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0          1 2011-01-01   0        0        6           1  0.24  0.2879  0.81
# 1          2 2011-01-01   1        0        6           1  0.22  0.2727  0.80
# 2          3 2011-01-01   2        0        6           1  0.22  0.2727  0.80
# 3          4 2011-01-01   3        0        6           1  0.24  0.2879  0.75
# 4          5 2011-01-01   4        0        6           1  0.24  0.2879  0.75
# ..       ...        ...  ..      ...      ...         ...   ...     ...   ...
# 605      606 2011-01-28  11        0        5           3  0.18  0.2121  0.93
# 606      607 2011-01-28  12        0        5           3  0.18  0.2121  0.93
# 607      608 2011-01-28  13        0        5           3  0.18  0.2121  0.93
# 608      609 2011-01-28  14        0        5           3  0.22  0.2727  0.80
# 609      610 2011-01-28  15        0        5           2  0.20  0.2576  0.86
#
#      windspeed  casual  registered  cnt
# 0       0.0000       3          13   16
# 1       0.0000       8          32   40
# 2       0.0000       5          27   32
# 3       0.0000       3          10   13
# 4       0.0000       0           1    1
# ..         ...     ...         ...  ...
# 605     0.1045       0          30   30
# 606     0.1045       1          28   29
# 607     0.1045       0          31   31
# 608     0.0000       2          36   38
# 609     0.0000       1          40   41
#
# [610 rows x 13 columns]

# %%
combine_data['atemp'].unique()
# Out:
# array([0.2879, 0.2727, 0.2576,    nan, 0.3485, 0.3939, 0.3333, 0.4242,
#        0.4545, 0.4394, 0.4091, 0.2273, 0.2121, 0.197 , 0.1364, 0.1061,
#        0.1212, 0.1667, 0.1818, 0.2424, 0.1515, 0.3182, 0.0606, 0.0758,
#        0.0909, 0.303 , 0.0303, 0.0455, 0.    , 0.0152])

# %%
combine_data['atemp'].isnull().sum()/combine_data['atemp'].shape[0]*100
# Out:
# 1.8032786885245904

# %%
atemp_mean=combine_data['atemp'].mean()

# %%
combine_data = combine_data.fillna(atemp_mean)
combine_data
# Out:
#      instant     dteday  hr  holiday  weekday  weathersit  temp   atemp   hum  \
# 0          1 2011-01-01   0        0        6           1  0.24  0.2879  0.81
# 1          2 2011-01-01   1        0        6           1  0.22  0.2727  0.80
# 2          3 2011-01-01   2        0        6           1  0.22  0.2727  0.80
# 3          4 2011-01-01   3        0        6           1  0.24  0.2879  0.75
# 4          5 2011-01-01   4        0        6           1  0.24  0.2879  0.75
# ..       ...        ...  ..      ...      ...         ...   ...     ...   ...
# 605      606 2011-01-28  11        0        5           3  0.18  0.2121  0.93
# 606      607 2011-01-28  12        0        5           3  0.18  0.2121  0.93
# 607      608 2011-01-28  13        0        5           3  0.18  0.2121  0.93
# 608      609 2011-01-28  14        0        5           3  0.22  0.2727  0.80
# 609      610 2011-01-28  15        0        5           2  0.20  0.2576  0.86
#
#      windspeed  casual  registered  cnt
# 0       0.0000       3          13   16
# 1       0.0000       8          32   40
# 2       0.0000       5          27   32
# 3       0.0000       3          10   13
# 4       0.0000       0           1    1
# ..         ...     ...         ...  ...
# 605     0.1045       0          30   30
# 606     0.1045       1          28   29
# 607     0.1045       0          31   31
# 608     0.0000       2          36   38
# 609     0.0000       1          40   41
#
# [610 rows x 13 columns]

# %%
combine_data['atemp'].median()
# Out:
# 0.197

# %%
combine_data['atemp'].isnull().sum()
# Out:
# 0

# %%
combine_data = combine_data.astype({"atemp": 'int',"dteday": 'int',"temp": 'int', "hum": 'int', "windspeed": 'int'})
combine_data.dtypes
# Out:
# instant       int64
# dteday        int64
# hr            int64
# holiday       int64
# weekday       int64
# weathersit    int64
# temp          int64
# atemp         int64
# hum           int64
# windspeed     int64
# casual        int64
# registered    int64
# cnt           int64
# dtype: object

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset_3=pd.read_excel('/content/drive/MyDrive/Internship_Project2/dataset_3.xlsx')

# %%
dataset_3
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620 2011-01-29       1   0     1   1    False        6           1
# 1        621 2011-01-29       1   0     1   2    False        6           1
# 2        622 2011-01-29       1   0     1   3    False        6           1
# 3        623 2011-01-29       1   0     1   4    False        6           1
# 4        624 2011-01-29       1   0     1   6    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      615 2011-01-28       1   0     1  20    False        5           2
# 386      616 2011-01-28       1   0     1  21    False        5           2
# 387      617 2011-01-28       1   0     1  22    False        5           1
# 388      618 2011-01-28       1   0     1  23    False        5           1
# 389      619 2011-01-29       1   0     1   0    False        6           1
#
#      temp   atemp   hum  windspeed  casual  registered  cnt
# 0    0.22  0.2273  0.64     0.1940       0          20   20
# 1    0.22  0.2273  0.64     0.1642       0          15   15
# 2    0.20  0.2121  0.64     0.1343       3           5    8
# 3    0.16  0.1818  0.69     0.1045       1           2    3
# 4    0.16  0.1818  0.64     0.1343       0           2    2
# ..    ...     ...   ...        ...     ...         ...  ...
# 385  0.24  0.2273  0.70     0.1940       1          61   62
# 386  0.22  0.2273  0.75     0.1343       1          57   58
# 387  0.24  0.2121  0.65     0.3582       0          26   26
# 388  0.24  0.2273  0.60     0.2239       1          22   23
# 389  0.22  0.1970  0.64     0.3582       2          26   28
#
# [390 rows x 16 columns]

# %%
dataset_3.dtypes
# Out:
# instant                int64
# dteday        datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                 bool
# weekday                int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
dataset_3_int = dataset_3.astype({"atemp": 'int',"dteday": 'int',"holiday": 'int',"temp": 'int', "hum": 'int', "windspeed": 'int'})
dataset_3_int.dtypes
# Out:
# instant       int64
# dteday        int64
# mnth          int64
# hr            int64
# holiday       int64
# weekday       int64
# weathersit    int64
# temp          int64
# atemp         int64
# hum           int64
# windspeed     int64
# casual        int64
# registered    int64
# cnt           int64
# dtype: object

# %%
dataset_3.duplicated().sum()
# Out:
# 0

# %%
dataset_3.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
dataset_3.describe()
# Out:
#            instant                         dteday  season     yr        mnth  \
# count   390.000000                            390   390.0  390.0  390.000000
# mean    805.500000  2011-02-05 11:45:13.846153728     1.0    0.0    1.800000
# min     611.000000            2011-01-28 00:00:00     1.0    0.0    1.000000
# 25%     708.250000            2011-02-01 00:00:00     1.0    0.0    2.000000
# 50%     805.500000            2011-02-05 12:00:00     1.0    0.0    2.000000
# 75%     902.750000            2011-02-10 00:00:00     1.0    0.0    2.000000
# max    1000.000000            2011-02-14 00:00:00     1.0    0.0    2.000000
# std     112.727548                            NaN     0.0    0.0    0.400514
#
#                hr     weekday  weathersit        temp       atemp         hum  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean    11.687179    2.989744    1.484615    0.220000    0.230424    0.613769
# min      0.000000    0.000000    1.000000    0.060000    0.075800    0.210000
# 25%      6.000000    1.000000    1.000000    0.160000    0.181800    0.450000
# 50%     12.000000    3.000000    1.000000    0.220000    0.227300    0.600000
# 75%     18.000000    5.000000    2.000000    0.260000    0.272700    0.750000
# max     23.000000    6.000000    3.000000    0.420000    0.424200    1.000000
# std      6.980295    2.149884    0.663805    0.073095    0.069455    0.202361
#
#         windspeed      casual  registered         cnt
# count  390.000000  390.000000  390.000000  390.000000
# mean     0.179416    5.576923   57.002564   62.579487
# min      0.000000    0.000000    0.000000    1.000000
# 25%      0.089600    1.000000   17.000000   18.500000
# 50%      0.164200    3.000000   48.000000   52.000000
# 75%      0.283600    6.000000   83.750000   88.750000
# max      0.582100   62.000000  236.000000  243.000000
# std      0.138551    9.317478   49.070198   53.274838

# %%
dataset_3['season'].unique()
# Out:
# array([1])

# %%
dataset_3.drop(['season'],axis=1,inplace=True)

# %%
dataset_3
# Out:
#      instant     dteday  yr  mnth  hr  holiday  weekday  weathersit  temp  \
# 0        620 2011-01-29   0     1   1    False        6           1  0.22
# 1        621 2011-01-29   0     1   2    False        6           1  0.22
# 2        622 2011-01-29   0     1   3    False        6           1  0.20
# 3        623 2011-01-29   0     1   4    False        6           1  0.16
# 4        624 2011-01-29   0     1   6    False        6           1  0.16
# ..       ...        ...  ..   ...  ..      ...      ...         ...   ...
# 385      615 2011-01-28   0     1  20    False        5           2  0.24
# 386      616 2011-01-28   0     1  21    False        5           2  0.22
# 387      617 2011-01-28   0     1  22    False        5           1  0.24
# 388      618 2011-01-28   0     1  23    False        5           1  0.24
# 389      619 2011-01-29   0     1   0    False        6           1  0.22
#
#       atemp   hum  windspeed  casual  registered  cnt
# 0    0.2273  0.64     0.1940       0          20   20
# 1    0.2273  0.64     0.1642       0          15   15
# 2    0.2121  0.64     0.1343       3           5    8
# 3    0.1818  0.69     0.1045       1           2    3
# 4    0.1818  0.64     0.1343       0           2    2
# ..      ...   ...        ...     ...         ...  ...
# 385  0.2273  0.70     0.1940       1          61   62
# 386  0.2273  0.75     0.1343       1          57   58
# 387  0.2121  0.65     0.3582       0          26   26
# 388  0.2273  0.60     0.2239       1          22   23
# 389  0.1970  0.64     0.3582       2          26   28
#
# [390 rows x 15 columns]

# %%
dataset_3['mnth'].unique()
# Out:
# array([1, 2])

# %%
dataset_3['yr'].unique()
# Out:
# array([0])

# %%
dataset_3.drop(['yr'],axis=1,inplace=True)

# %%
dataset_3
# Out:
#      instant     dteday  mnth  hr  holiday  weekday  weathersit  temp   atemp  \
# 0        620 2011-01-29     1   1    False        6           1  0.22  0.2273
# 1        621 2011-01-29     1   2    False        6           1  0.22  0.2273
# 2        622 2011-01-29     1   3    False        6           1  0.20  0.2121
# 3        623 2011-01-29     1   4    False        6           1  0.16  0.1818
# 4        624 2011-01-29     1   6    False        6           1  0.16  0.1818
# ..       ...        ...   ...  ..      ...      ...         ...   ...     ...
# 385      615 2011-01-28     1  20    False        5           2  0.24  0.2273
# 386      616 2011-01-28     1  21    False        5           2  0.22  0.2273
# 387      617 2011-01-28     1  22    False        5           1  0.24  0.2121
# 388      618 2011-01-28     1  23    False        5           1  0.24  0.2273
# 389      619 2011-01-29     1   0    False        6           1  0.22  0.1970
#
#       hum  windspeed  casual  registered  cnt
# 0    0.64     0.1940       0          20   20
# 1    0.64     0.1642       0          15   15
# 2    0.64     0.1343       3           5    8
# 3    0.69     0.1045       1           2    3
# 4    0.64     0.1343       0           2    2
# ..    ...        ...     ...         ...  ...
# 385  0.70     0.1940       1          61   62
# 386  0.75     0.1343       1          57   58
# 387  0.65     0.3582       0          26   26
# 388  0.60     0.2239       1          22   23
# 389  0.64     0.3582       2          26   28
#
# [390 rows x 14 columns]

# %%
dataset_3.shape
# Out:
# (390, 14)
